# %% [markdown]
# # 训练成功启动

# %% [markdown]
# <br>参数设置
# <br>model：T5-3B
# <br>stage3_max_live_parameters: 1e11
# <br>stage3_max_reuse_distance: 1e11
# <br>虚拟内存 swapfile：30GB

# %% [markdown]
# ![11.png](attachment:c7fe2def-7b4c-470f-9a79-9bb4a88af235.png)

# %% [markdown]
# # 训练意外终止

# %% [markdown]
# <br> 1.GPU Memory Usage达到7784MB后不再加载，继续加大"stage3_max_live_parameters"并未提高GPU显存的加载。
# <br> 2.训练到 step 5 时被杀进程，原因未知。多次尝试，始终是这个情况。
# <br> 3.启用30GB虚拟内存，但虚拟内存从未得到加载，一直是0K状态。

# %% [markdown]
# ![22.png](attachment:e102f12a-8838-4df6-8d17-7674f3ae56ea.png)
